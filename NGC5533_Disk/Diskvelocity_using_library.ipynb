# %%
#Imports
import sys
sys.path.append('../python/')
import NGC5533_functions as nf
import NGC5533_functions_test as nft

import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(9.0,8.0))

plt.xlim(0,120)
#plt.ylim(0,450)

r = np.linspace(0.1,120,100)
pref=0.3

def disk(r,pref,h,drho00):
    return nf.d_v(r,pref,nf.h_c,nf.drho00_c, load=True)
def halo(r,rc,hrho00):
    return nf.h_v(r,nf.h_rc,nf.hrho00_c, load=True)

def diskminushalo(r,pref,h,drho00,rc,hrho00):
    return np.sqrt((disk(r,pref,h,drho00)**2)-(halo(r,rc,hrho00)**2))

def f(r):
    return 937.5 / np.sqrt(r)

rplot = np.linspace(40,120,100)
plt.plot(rplot, f(rplot),'purple',label='1/sqrt(r)')
plt.plot(r,nf.d_v(r,pref,nf.h_c,nf.drho00_c,load=True),label='Disk: from library ')
plt.plot(r,diskminushalo(r,pref,nf.h_c,nf.drho00_c,nf.h_rc,nf.hrho00_c), label='Disk minus Halo')
#plt.plot(r,nf.d_v(r,pref=1,nf.h_c,nf.drho00_c),label='Disk: from library (innerintegral: 0 to 125)')
#plt.plot(r,nft.d_v(r,pref=1,nf.h_c,nf.drho00_c),label='Disk: from test library (innerintegral: 0 to inf)')
#plt.plot(r,nf.b_v(r,nf.n_c,nf.re_c,load=True),label='Bulge: from library')
plt.plot(r,nf.h_v(r,nf.h_rc,nf.hrho00_c,load=True),label='Halo: from library')

plt.legend()
plt.show()
# Out:
# C:\Users\JB\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in sqrt
#   from ipykernel import kernelapp as app

# %%
print("p(x) = {}".format(nf.d_px(1,1,0)))
print("R(h) + d(h) = {}".format(nf.R(nf.h_c)+nf.d(nf.h_c)))
print("z(h) = {}".format(nf.z0(nf.h_c)))
print("R(h) = {}".format(nf.R(nf.h_c)))
print("d(h) = {}".format(nf.d(nf.h_c)))
print("rho(R+d,h,d_rho00_c) = {}".format(nf.d_rho0(nf.R(nf.h_c)+nf.d(nf.h_c), nf.h_c, nf.drho00_c)))
print("rho(R+d+0.0001,h,drho00_c) = {}".format(nf.d_rho0(nf.R(nf.h_c)+nf.d(nf.h_c)+0.001, nf.h_c, nf.drho00_c)))
print("durho(R+d,h,drho00_c) = {}".format(nf.d_durho0(nf.R(nf.h_c)+nf.d(nf.h_c), nf.h_c, nf.drho00_c)))
print("durho(R+d+0.0001,h,drho00_c) = {}".format(nf.d_durho0(nf.R(nf.h_c)+nf.d(nf.h_c)+0.001, nf.h_c, nf.drho00_c)))
print("rho_rz(R+d,z=1,h,drho00_c) = {}".format(nf.d_rho_rz(nf.R(nf.h_c)+nf.d(nf.h_c), 1.0, nf.h_c, nf.drho00_c)))
print("rho_rz(R+d+0.0001,z=1,h,drho00_c) = {}".format(nf.d_rho_rz(nf.R(nf.h_c)+nf.d(nf.h_c)+0.001, 1.0, nf.h_c, nf.drho00_c)))
print("drho_rz(R+d,z=1,h,drho00_c) = {}".format(nf.d_drho_rz(nf.R(nf.h_c)+nf.d(nf.h_c), 1.0, nf.h_c, nf.drho00_c)))
print("drho_rz(R+d+0.0001,z=1,h,drho00_c) = {}".format(nf.d_drho_rz(nf.R(nf.h_c)+nf.d(nf.h_c)+0.001, 1.0, nf.h_c, nf.drho00_c)))
print("K(1,1,1) (complete elliptic integral) = {}".format(nf.d_K(r=1,u=1,xi=1)))
print("innerfunction(1,1,1) = {}".format(nf.d_innerfunc(1,1,1,nf.h_c,nf.drho00_c)))
print("innerintegral(1,1) = {}".format(nf.d_innerintegral(1,1,nf.h_c,nf.drho00_c)))
print("outerintegral(10) = {}".format(nf.d_outerintegral(10,nf.h_c,nf.drho00_c)))
print("F(10) = {}".format(nf.d_F(1,nf.h_c,nf.drho00_c,1)))

# %%
fig = plt.figure(figsize=(9.0,8.0))

plt.xlim(0,25)
#plt.ylim(0,450)

r = np.linspace(0.1,25,100)

plt.plot(r,nf.d_v(r,pref,nf.h_c,nf.drho00_c),label='Disk: from library')
#plt.plot(r,nf.d_v(r,pref=1,nf.h_c,nf.drho00_c),label='Disk: from library (innerintegral: 0 to 125)')
#plt.plot(r,nft.d_v(r,pref=1,nf.h_c,nf.drho00_c),label='Disk: from test library (innerintegral: 0 to inf)')
plt.plot(r,nf.b_v(r,nf.n_c,nf.re_c),label='Bulge: from library')
plt.plot(r,nf.h_v(r,nf.h_rc,nf.hrho00_c),label='Halo: from library')

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(9.0,8.0))

plt.xlim(0,120)
#plt.ylim(0,450)

r = np.linspace(0.1,120,100)

plt.plot(r,nf.d_v(r,pref,1,nf.drho00_c),label='Disk: from library but with h=1')
plt.plot(r,nf.d_v(r,pref,2,nf.drho00_c),label='Disk: from library but with h=2')
plt.plot(r,nf.d_v(r,pref,3,nf.drho00_c),label='Disk: from library but with h=3')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-96de6b55a2b0> in <module>
#       6 r = np.linspace(0.1,120,100)
#       7
# ----> 8 plt.plot(r,nf.d_v(r,pref,1,nf.drho00_c),label='Disk: from library but with h=1')
#       9 plt.plot(r,nf.d_v(r,pref,2,nf.drho00_c),label='Disk: from library but with h=2')
#      10 plt.plot(r,nf.d_v(r,pref,3,nf.drho00_c),label='Disk: from library but with h=3')
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_v(r, pref, h, d_rho00, save, load, comp, **kwargs)
#     424     if save:
#     425         r = np.asarray(r)
# --> 426         a = np.sqrt(-r*d_Fv(r,h,d_rho00,pref))
#     427         a[np.isnan(a)] = 0
#     428         savedata(r,a,comp,'h'+str(h)+'d_rho00'+str(d_rho00)+'pref'+str(pref),file=comp+'.hdf5',**kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    1970             vargs.extend([kwargs[_n] for _n in names])
#    1971
# -> 1972         return self._vectorize_call(func=func, args=vargs)
#    1973
#    1974     def _get_ufunc_and_otypes(self, func, args):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2046                       for a in args]
#    2047
# -> 2048             outputs = ufunc(*inputs)
#    2049
#    2050             if ufunc.nout == 1:
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_F(r, h, d_rho00, pref)
#     388     if pref == False:
#     389         pref = epsdisk*(L0/d_Mdblintrho(h,d_rho00))
# --> 390     val = 4*np.pi*G*d_outerintegral(r,h,d_rho00)*pref
#     391     if np.isnan(val):
#     392         return 0
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_outerintegral(r, h, d_rho00)
#     376
#     377 def d_outerintegral(r,h=h_c,d_rho00=drho00_c): #Integrate Outer Function
# --> 378     return si.quad(d_innerintegral, 0, np.inf, args=(r,h,d_rho00))[0]
#     379
#     380 def d_Mdblintrho(h=h_c,d_rho00=drho00_c):    #M double-integral rho
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\integrate\quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\integrate\quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
# --> 450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#     451     else:
#     452         if infbounds != 0:
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_innerintegral(u, r, h, d_rho00)
#     372
#     373 def d_innerintegral(u,r,h=h_c,d_rho00=drho00_c): #Integrate Function
# --> 374     return u*si.quad(d_innerfunc, 0, 125, args=(r,u,h,d_rho00))[0]
#     375 #Args passed into quad need to be numbers, not arrays. (?)
#     376
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\integrate\quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\integrate\quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     446     if points is None:
#     447         if infbounds == 0:
# --> 448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
#     450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_innerfunc(z, r, u, h, d_rho00)
#     369
#     370 def d_innerfunc(z,r,u,h=h_c,d_rho00=drho00_c):  #Inner Function (3D)
# --> 371     return d_drho_rz(u, z, h, d_rho00)*d_K(r,u,z)
#     372
#     373 def d_innerintegral(u,r,h=h_c,d_rho00=drho00_c): #Integrate Function
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_K(r, u, xi)
#     366
#     367 def d_K(r,u,xi): #Complete Elliptic Integral
# --> 368     return 2*(ss.ellipk(d_px(r,u,xi)) - ss.ellipe(d_px(r,u,xi)))/(np.pi*np.sqrt(r*u*d_px(r,u,xi)))
#     369
#     370 def d_innerfunc(z,r,u,h=h_c,d_rho00=drho00_c):  #Inner Function (3D)
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_px(r, u, xi)
#     334     x = lambda r,u,xi: (r**2+u**2+xi**2)/(2*r*u)
#     335     try:
# --> 336         return x(r,u,xi)-(np.sqrt(x(r,u,xi)**2-1))
#     337     except ZeroDivisionError: #If dividing by zero, return infinity instead of error. (Mostly at 0)
#     338         return np.nan
#
# KeyboardInterrupt:
