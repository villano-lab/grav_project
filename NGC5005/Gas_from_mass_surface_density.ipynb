# %%
# Import
import numpy as np
import matplotlib.pyplot as plt

# %%
# from https://academic.oup.com/mnras/article/449/4/3981/1195237#92052944 (fig.8)
# DataThief

# Radius in arcsec
gasmsd_arcsec = np.loadtxt("../data/gasmsd_arcsec_log.txt")
rarcsec, gasmsd_log = gasmsd_arcsec.T

# Radius in kpc
gasmsd_kpc = np.loadtxt("../data/gasmsd_kpc_log.txt")
rkpc = gasmsd_kpc.T[0]

# Change log scale to linear scale
gasmsd_linear = np.power(10, gasmsd_log)

# Save it to text file
# Radius in arcsec
np.savetxt("../data/gasmsd_arcsec_linear.txt", 
           np.transpose([rarcsec, gasmsd_linear]), 
           delimiter='\t', 
           fmt='%10.5f',
           header='Datathief \n Gas mass density from https://academic.oup.com/mnras/article/449/4/3981/1195237#92052944 (fig.8) \n log scale converted to linear in python \n units: x-axis: arcsec, y-axis: mass surface density (Msun pc^-2)')

# Radius in kpc
np.savetxt("../data/gasmsd_kpc_linear.txt", 
           np.transpose([rkpc, gasmsd_linear]), 
           delimiter='\t', 
           fmt='%10.5f',
           header='Datathief \n Gas mass density from https://academic.oup.com/mnras/article/449/4/3981/1195237#92052944 (fig.8) \n log scale converted to linear in python \n units: x-axis: kpc, y-axis: mass surface density (Msun pc^-2)')
# Out:
# [ 2.7900e+00  2.7262e+00  2.6732e+00  2.5710e+00  2.5290e+00  2.4414e+00
#   2.3939e+00  2.3300e+00  2.2881e+00  2.2479e+00  2.1785e+00  2.1420e+00
#   2.1055e+00  2.0781e+00  2.0471e+00  2.0088e+00  1.9211e+00  1.8956e+00
#   1.8646e+00  1.8080e+00  1.7806e+00  1.7624e+00  1.7186e+00  1.6949e+00
#   1.6766e+00  1.6621e+00  1.6639e+00  1.6676e+00  1.6549e+00  1.6659e+00
#   1.6860e+00  1.6714e+00  1.6550e+00  1.6642e+00  1.6604e+00  1.6204e+00
#   1.5967e+00  1.5693e+00  1.5310e+00  1.5072e+00  1.4781e+00  1.4453e+00
#   1.4051e+00  1.3723e+00  1.3412e+00  1.3193e+00  1.2883e+00  1.2609e+00
#   1.2372e+00  1.2135e+00  1.1898e+00  1.1623e+00  1.1387e+00  1.1205e+00
#   1.0840e+00  1.0676e+00  1.0512e+00  1.0311e+00  1.0129e+00  9.8910e-01
#   9.7460e-01  9.5450e-01  9.4000e-01  9.2900e-01  9.1250e-01  8.9610e-01
#   8.8890e-01  8.8170e-01  8.7260e-01  8.6160e-01  8.5250e-01  8.4340e-01
#   8.3250e-01  8.1970e-01  8.0880e-01  7.9790e-01  7.8880e-01  7.7970e-01
#   7.7600e-01  7.7060e-01  7.6330e-01  7.5790e-01  7.4880e-01  7.3970e-01
#   7.3420e-01  7.2690e-01  7.1970e-01  7.0330e-01  6.9600e-01  6.9240e-01
#   6.8510e-01  6.7420e-01  6.6510e-01  6.5420e-01  6.3780e-01  6.2320e-01
#   6.0860e-01  5.9770e-01  5.8130e-01  5.6850e-01  5.5030e-01  5.3560e-01
#   5.1920e-01  4.9740e-01  4.7740e-01  4.5730e-01  4.3540e-01  4.1720e-01
#   3.9170e-01  3.6790e-01  3.4790e-01  3.2420e-01  2.9130e-01  2.6760e-01
#   2.4210e-01  2.2570e-01  2.0190e-01  1.7820e-01  1.5620e-01  1.2900e-01
#   1.0520e-01  7.9600e-02  5.6000e-02  2.3100e-02 -6.0500e-04 -2.2500e-02
#  -4.9900e-02 -7.1800e-02 -9.9100e-02 -1.2290e-01 -1.4480e-01 -1.6850e-01
#  -1.9770e-01 -2.2510e-01 -2.5060e-01 -2.7620e-01 -3.0720e-01 -3.4010e-01
#  -3.6380e-01 -3.8570e-01 -4.1130e-01 -4.4230e-01 -4.7880e-01 -5.0980e-01
#  -5.3720e-01 -5.6460e-01]

# %%
# Plot Gas mass surface density in kpc
plt.figure(figsize=(9,8))
plt.scatter(rkpc,gasmsd_linear)
plt.title("Gas mass surface density")
plt.xlabel("Radius (kpc)")
plt.ylabel("Gas mass surface density ($M_\odot$ $pc^{-2}$)")
plt.show()

# %%
# Plot Gas mass surface density in arcsec
plt.figure(figsize=(9,8))
plt.scatter(rarcsec,gasmsd_linear)
plt.title("Gas mass surface density")
plt.xlabel("Radius (arcsec)")
plt.ylabel("Gas mass surface density ($M_\odot$ $pc^{-2}$)")
plt.show()
