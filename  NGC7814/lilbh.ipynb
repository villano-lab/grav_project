# %%
from matplotlib import pyplot as plt
import cv2
import random

img1 = cv2.imread('galaxy.jpg')
wi=500
hi=500
dsize = (w, h)
img1=cv2.resize(img1, dsize)
def main():
    x = np.linspace(0, 1000, 50) 
    r=100
    h,k=(wi/2,hi/2)
    y = (r**2-(x-h)**2)**.5 +k
    y2=
    plt.figure(figsize=(20,10))
    imscatter(x, y, 'blackhole1.png',zoom=.05)
    imscatter(x, y2, 'blackhole1.png',zoom=.05)
    plt.plot(x, y)
    plt.plot(x,y2)
    color = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    plt.imshow(color)
    plt.title('Image')
    plt.axis('off')
    plt.show()
main()
# Out:
# <ipython-input-87-c0de47485615>:14: RuntimeWarning: invalid value encountered in sqrt
#   y = (r**2-(x-h)**2)**.5 +k
