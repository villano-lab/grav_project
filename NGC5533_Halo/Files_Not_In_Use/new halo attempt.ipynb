# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import scipy.integrate as integrate
from scipy.integrate import quad
from scipy.special import ellipe
from scipy.special import ellipk


rc = 1.7                                                  #for NGC5533 [kpc]
rho_0 = .23e9                                             #for NGC5533 [solar masses per kpc^3]

r = np.linspace(0, 25, 500)
R = np.linspace(0, 25, 500)
rho_urc = lambda r: rho_0*(rc**3)/((r+rc)+(r**2+rc**2))
print(rho_urc(1))
# Out:
# 171470409.71168435

# %%
#rotation curve for halo

G = 4.300e-6                                                #gravitational constant (kpc/solar mass*(km/s)^2)
z = 1.0                                                    #thickness of galactic plane?
vh = lambda r: np.sqrt(4*np.pi*G*(r**2+z**2)*rho_urc(r))        #from casertano eq 9 solved for v
print(vh(0))
# Out:
# 115.33738938543404

# %%
#plot halo velocity
fig = plt.figure(figsize=(9.0,8.0))                #size of the plot
ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

r = np.linspace(0, 100, 50)
plt.plot(r, vh(r), linestyle='solid', label='Disk Velocity')          

plt.axis('tight');                                 #xmin, xmax, ymin, ymax
                                                   #or use: plt.xlim(10, 0) plt.ylim(1.2, -1.2);
                                                   #or to tighten the bounds: plt.axis('tight')
                                                   #or use: plt.axis([0, 15000, 0.5e6, 2.5e6])

fig.suptitle('Halo Velocity', fontsize=18)
ax.set(title='Halo Component NGC 5533')              #labeling axes
ax.set_xlim(0, 100)
ax.set_xlabel('r (kpc)', fontsize=14)
ax.set_ylabel('v (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend(fontsize=16);                                   #adding legend
plt.savefig('Halo Velocity200pts.png')
plt.show()

# %%
hh = lambda r: 4*np.pi*rho_urc(r)*R**2

vhh = lambda r: quad(hh, 0, r, args=(R))[0]

# %%
#plot halo velocity
fig = plt.figure(figsize=(9.0,8.0))                #size of the plot
ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

r = np.linspace(0, 100, 50)
plt.plot(any(r), any(vhh(r)), linestyle='solid', label='Disk Velocity')          

plt.axis('tight');                                 #xmin, xmax, ymin, ymax
                                                   #or use: plt.xlim(10, 0) plt.ylim(1.2, -1.2);
                                                   #or to tighten the bounds: plt.axis('tight')
                                                   #or use: plt.axis([0, 15000, 0.5e6, 2.5e6])

fig.suptitle('Halo Velocity', fontsize=18)
ax.set(title='Halo Component NGC 5533')              #labeling axes
ax.set_xlim(0, 100)
ax.set_xlabel('r (kpc)', fontsize=14)
ax.set_ylabel('v (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend(fontsize=16);                                   #adding legend
plt.savefig('Halo Velocity200pts.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e1ae995b9dcd> in <module>
#       6
#       7 r = np.linspace(0, 100, 50)
# ----> 8 plt.plot(any(r), any(vhh(r)), linestyle='solid', label='Disk Velocity')
#       9
#      10 plt.axis('tight');                                 #xmin, xmax, ymin, ymax
#
# <ipython-input-5-f6fcfd6c1b8f> in <lambda>(r)
#       1 hh = lambda r: 4*np.pi*rho_urc(r)*R**2
#       2
# ----> 3 vhh = lambda r: quad(hh, 0, r, args=(R))[0]
#
# ~\Anaconda3\lib\site-packages\scipy\integrate\quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     335
#     336     # check the limits of integration: \int_a^b, expect a < b
# --> 337     flip, a, b = b < a, min(a, b), max(a, b)
#     338
#     339     if weight is None:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
