# %%
>>> from astroquery.alma import Alma
>>> m83_data = Alma.query_object('M83')
>>> print(len(m83_data))
# Out:
# ---------------------------------------------------------------------------
# InvalidQueryError                         Traceback (most recent call last)
# <ipython-input-7-fa1add200093> in <module>
#       1 from astroquery.alma import Alma
# ----> 2 m83_data = Alma.query_object('M83')
#       3 print(len(m83_data))
#
# ~\anaconda3\lib\site-packages\astroquery\utils\class_or_instance.py in f(*args, **kwds)
#      23         def f(*args, **kwds):
#      24             if obj is not None:
# ---> 25                 return self.fn(obj, *args, **kwds)
#      26             else:
#      27                 return self.fn(cls, *args, **kwds)
#
# ~\anaconda3\lib\site-packages\astroquery\utils\process_asyncs.py in newmethod(self, *args, **kwargs)
#      24             verbose = kwargs.pop('verbose', False)
#      25
# ---> 26             response = getattr(self, async_method_name)(*args, **kwargs)
#      27             if kwargs.get('get_query_payload') or kwargs.get('field_help'):
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidQueryError                         Traceback (most recent call last)
# <ipython-input-5-e19700907f64> in <module>
# ----> 1 m83_data = Alma.query_object('M83')
#
# ~\anaconda3\lib\site-packages\astroquery\utils\class_or_instance.py in f(*args, **kwds)
#      23         def f(*args, **kwds):
#      24             if obj is not None:
# ---> 25                 return self.fn(obj, *args, **kwds)
#      26             else:
#      27                 return self.fn(cls, *args, **kwds)
#
# ~\anaconda3\lib\site-packages\astroquery\utils\process_asyncs.py in newmethod(self, *args, **kwargs)
#      24             verbose = kwargs.pop('verbose', False)
#      25
# ---> 26             response = getattr(self, async_method_name)(*args, **kwargs)
#      27             if kwargs.get('get_query_payload') or kwargs.get('field_help'):
#      28                 return response
#
# ...
