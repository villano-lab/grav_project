# %%
#Imports
import sys
sys.path.append('../python/')
import NGC5533_functions as nf

import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
import lmfit as lm
import dataPython as dp

# %%
data = dp.getXYdata_wXYerr('data/100kpc_data.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

#change r_dat so it's strictly increasing
r_dat, v_dat, v_err0, v_err1 = (list(a) for a in zip(*sorted(zip(r_dat, v_dat, v_err0, v_err1))))
#converting v_err1 to an array
v_err1 = np.asarray(v_err1)

# %%
def f(r,rc,h_rho00):
     return np.sqrt(nf.bh_v(r_dat,load=True)**2 + nf.h_v(r,rc,h_rho00,load=True)**2 + nf.b_v(r,load=True)**2 + nf.d_v(r,load=True)**2)

# %%
#Setup
weighdata = 1/v_err1
l_mod = lm.Model(f)
params = l_mod.make_params()
#Black Hole
params.add('M', value=nf.Mbh_def, min=0) #Mass
#Bulge
params.add('n', value=nf.n_c, min=0) 
params.add('re', value=nf.re_c, min=0) 
#Disk
params.add('h', value=nf.h_c, min=0, max=1000)
params.add('d_rho00', value=nf.drho00_c, min=0)
#Halo
params.add('rc', value=nf.h_rc, min=0)   #Radius (magnitude)
params.add('h_rho00', value=nf.hrho00_c, min=0) #Density (halo)

#Do fit
l_fit = l_mod.fit(v_dat,params,r=r_dat,weights=weighdata)

# %%
#Define Stuff
l_dict = l_fit.best_values
#Halo
l_rc = l_dict['rc']
l_h_rho00 = l_dict['h_rho00']

l_curve = f(r_dat,l_rc,l_h_rho00)

# %%
fig = plt.figure(figsize=(9.0,8.0))

plt.xlim(0,125)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')
plt.plot(r_dat,l_curve,label='Fit')
plt.plot(r_dat,nf.h_v(r_dat,l_rc,l_h_rho00,load=True),label='Halo Only')
plt.plot(r_dat,nf.h_v(r_dat,load=True),label='Halo (Defaults)')

plt.legend()
plt.savefig('Fitting_with_library.png')
plt.show()

l_fit
# Out:
# <h2> Model</h2> Model(f) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>9</td><td></td></tr><tr><td># data points</td><td>69</td><td></td></tr><tr><td># variables</td><td>7</td><td></td></tr><tr><td>chi-square</td><td> 755883.998</td><td></td></tr><tr><td>reduced chi-square</td><td> 12191.6774</td><td></td></tr><tr><td>Akaike info crit.</td><td> 655.806032</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 671.444778</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> rc </td><td>  1.40000000 </td><td> 1.4 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> h_rho00 </td><td>  3.1000e+08 </td><td> 310000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> M </td><td>  2.7000e+09 </td><td> 2700000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> n </td><td>  2.70000000 </td><td> 2.7 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> re </td><td>  2.60000000 </td><td> 2.6 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> h </td><td>  8.90000000 </td><td> 8.9 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> d_rho00 </td><td>  3.1000e+08 </td><td> 310000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %%
fig = plt.figure(figsize=(9.0,8.0))

plt.xlim(0,25)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')
plt.plot(r_dat,l_curve,label='Fit')
plt.plot(r_dat,nf.h_v(r_dat,l_rc,l_h_rho00,load=True),label='Halo Only')
plt.plot(r_dat,nf.h_v(r_dat,load=True),label='Halo (Defaults)')

plt.legend()
plt.savefig('Fitting_with_library.png')
plt.show()

l_fit
# Out:
# <h2> Model</h2> Model(f) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>9</td><td></td></tr><tr><td># data points</td><td>69</td><td></td></tr><tr><td># variables</td><td>7</td><td></td></tr><tr><td>chi-square</td><td> 755883.998</td><td></td></tr><tr><td>reduced chi-square</td><td> 12191.6774</td><td></td></tr><tr><td>Akaike info crit.</td><td> 655.806032</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 671.444778</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> rc </td><td>  1.40000000 </td><td> 1.4 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> h_rho00 </td><td>  3.1000e+08 </td><td> 310000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> M </td><td>  2.7000e+09 </td><td> 2700000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> n </td><td>  2.70000000 </td><td> 2.7 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> re </td><td>  2.60000000 </td><td> 2.6 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> h </td><td>  8.90000000 </td><td> 8.9 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> d_rho00 </td><td>  3.1000e+08 </td><td> 310000000.0 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>
