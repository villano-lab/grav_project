# %%
#Imports
import sys
sys.path.append('../../python/')
import NGC5533_functions as nf

import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
import lmfit as lm
import dataPython as dp

from datetime import datetime
import time as t

# %%
starttime = t.time()

data = dp.getXYdata_wXYerr('../data/100kpc_data.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

#change r_dat so it's strictly increasing
r_dat, v_dat, v_err0, v_err1 = (list(a) for a in zip(*sorted(zip(r_dat, v_dat, v_err0, v_err1))))
#converting v_err1 to an array
v_err1 = np.asarray(v_err1)
#Express as weights
weighdata = 1/v_err1

# %%
#keeping others but holding them constant
def f(r,rc,h_rho00):
     return np.sqrt(nf.bh_v(r_dat,load=True,path='../')**2 
                    + nf.h_v(r,rc,h_rho00,load=False,path='../')**2 
                    + nf.b_v(r,load=True,path='../')**2 
                    + nf.d_v(r,pref=0.5,load=True,path='../')**2)
#Only Halo
def h(r,rc,h_rho00):
    return nf.h_v(r,rc,h_rho00,load=True,path='../')

# %%
#Fit, Keeping rest constant

#Setup
l_mod = lm.Model(f)
l_params = l_mod.make_params()
#Bulge Params
l_params.add('rc', value=nf.n_c, min=0) 
l_params.add('h_rho00', value=nf.re_c, min=0) 
#Do fit
l_fit = l_mod.fit(v_dat,l_params,r=r_dat,weights=weighdata)

# %%
#Fit, H Only

#Setup
h_mod = lm.Model(h)
h_params = h_mod.make_params()
#Bulge Params
h_params.add('rc', value=nf.n_c, min=0) 
h_params.add('h_rho00', value=nf.re_c, min=0) 
#Do fit
h_fit = h_mod.fit(v_dat,h_params,r=r_dat,weights=weighdata)

# %%
#Define curves to plot

l_dict = l_fit.best_values
l_rc = l_dict['rc']
l_h_rho00 = l_dict['h_rho00']
l_curve = f(r_dat,l_rc,l_h_rho00)

h_dict = h_fit.best_values
h_rc = h_dict['rc']
h_h_rho00 = h_dict['h_rho00']

# %%
fig = plt.figure(figsize=(9.0,8.0))

plt.xlim(0,125)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')
plt.plot(r_dat,l_curve,'b-',label='Fit with All Components')
plt.plot(r_dat,nf.h_v(r_dat,l_rc,l_h_rho00,path='../',load=False),'b--',label='Halo Only, from All Components')
plt.plot(r_dat,nf.h_v(r_dat,path='../'),'g-.',label='Halo (Defaults)')
plt.plot(r_dat,nf.h_v(r_dat,h_rc,h_h_rho00,load=False,path='../'),label='Fit Halo Only')
#I tried the above without calling the load function; that is not the issue.

plt.legend()
plt.show()

print('Fit information for all-component fit:')
l_fit
# Out:
# Fit information for all-component fit:
# <h2> Model</h2> Model(f) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>90</td><td></td></tr><tr><td># data points</td><td>69</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 3207.76469</td><td></td></tr><tr><td>reduced chi-square</td><td> 47.8770850</td><td></td></tr><tr><td>Akaike info crit.</td><td> 268.906395</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 273.374608</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> rc </td><td>  440758.718 </td><td>  44586.5624 </td><td> (10.12%) </td><td> 2.7 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> h_rho00 </td><td>  170119.187 </td><td>  24093.8918 </td><td> (14.16%) </td><td> 2.6 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %%
fig = plt.figure(figsize=(9.0,8.0))

plt.xlim(0,25)
plt.ylim(0,400)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')
plt.plot(r_dat,l_curve,'b-',label='Fit with All Components')
plt.plot(r_dat,nf.h_v(r_dat,l_rc,l_h_rho00,load=True,path='../'),'b--',label='Halo Only, from All Components')
plt.plot(r_dat,nf.h_v(r_dat,load=True,path='../'),'g-.',label='Halo (Defaults)')
plt.plot(r_dat,nf.h_v(r_dat,h_rc,h_h_rho00,load=True,path='../'),label='Fit Halo Only')

plt.legend()
plt.show()

print('Fit information for single-component fit')
h_fit
# Out:
# Fit information for single-component fit
# <h2> Model</h2> Model(h) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>75</td><td></td></tr><tr><td># data points</td><td>69</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 131394.269</td><td></td></tr><tr><td>reduced chi-square</td><td> 1961.10849</td><td></td></tr><tr><td>Akaike info crit.</td><td> 525.077737</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 529.545950</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> rc </td><td>  294652.192 </td><td>  8475.12182 </td><td> (2.88%) </td><td> 2.7 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr><tr><td> h_rho00 </td><td>  813195.411 </td><td>  185364.868 </td><td> (22.79%) </td><td> 2.6 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %%
endtime = t.time()
print('Total Time:')
print(str(endtime - starttime)+' seconds')
print('')

print('Timestamp:')
print(datetime.now())
# Out:
# Total Time:
# 1.7894306182861328 seconds
#
# Timestamp:
# 2019-11-07 09:40:41.986943
