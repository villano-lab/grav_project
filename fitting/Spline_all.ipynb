# %%
import sys
sys.path.append('../python/')
import NGC5533_functions as nf
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import InterpolatedUnivariateSpline

# %%
#Bulge

r = np.linspace(0.1,20,10)
#b_c = 1
#print(nf.b_vsquarev([1,2],2.5)**(1/2))
#vbspline = InterpolatedUnivariateSpline(r, b_c*nf.b_v(r), k=3)    #turns array vb into an approximate function
vbspline = InterpolatedUnivariateSpline(r, nf.b_v(r), k=3)
#print(vbspline.get_coeffs())

# %%
# Bulge spline plot

fig = plt.figure(figsize=(9.0,8.0))

plt.plot(r,vbspline(r),label='Bulge Spline')

plt.legend()
plt.show()

# %%
# Disk

r = np.linspace(0.1,20,10)
pref = 1
#d_c = 1
vdspline = InterpolatedUnivariateSpline(r, nf.d_v(r, pref), k=3)    #turns array vb into an approximate function
# Out:
# ../python/NGC5533_functions.py:275: RuntimeWarning: overflow encountered in cosh
#   return d_durho0(r, h, d_rho00)*np.power(np.cosh(z/z0(h)), -2)
# ../python/NGC5533_functions.py:281: RuntimeWarning: invalid value encountered in double_scalars
#   return u*d_drho_rz(u, z, h, d_rho00)*(2*d_K(r,u,z))/(np.pi*np.sqrt(r*u*d_px(r,u,z)))
# ../python/NGC5533_functions.py:284: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return si.quad(d_innerfunc, 0, np.inf, args=(r,u,h,d_rho00))[0]
# ../python/NGC5533_functions.py:287: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   return si.quad(d_innerintegral, 0, np.inf, args=(r,h,d_rho00))[0]

# %%
# Black Hole

r = np.linspace(0.1,20,10)
#bh_c = 1
vbhspline = InterpolatedUnivariateSpline(r, nf.bh_v(r), k=3)    #turns array vb into an approximate function

# %%
# Halo

r = np.linspace(0.1,20,10)
#h_c = 1
vhalospline = InterpolatedUnivariateSpline(r, nf.h_v(r), k=3)    #turns array vb into an approximate function

# %%
# Spline plot

fig = plt.figure(figsize=(9.0,8.0))

plt.plot(r,vbspline(r),label='Bulge Spline')
#plt.plot(r,vdspline(r),label='Disk Spline')
plt.plot(r,vbhspline(r),label='Black Hole Spline')
plt.plot(r,vhalospline(r),label='Halo Spline')

plt.legend()
plt.show()
