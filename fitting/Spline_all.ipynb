# %%
import sys
sys.path.append('../python/')
import NGC5533_functions as nf
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import InterpolatedUnivariateSpline

# %%
#Bulge

r = np.linspace(0.1,20,10)
#b_c = 1
#print(nf.b_vsquarev([1,2],2.5)**(1/2))
#vbspline = InterpolatedUnivariateSpline(r, b_c*nf.b_v(r), k=3)    #turns array vb into an approximate function
vbspline = InterpolatedUnivariateSpline(r, nf.b_v(r), k=3)
#print(vbspline.get_coeffs())

# %%
# Bulge spline plot

fig = plt.figure(figsize=(9.0,8.0))

plt.plot(r,vbspline(r),label='Bulge Spline')

plt.legend()
plt.show()

# %%
# Disk

r = np.linspace(0.1,20,10)
pref = 1
#d_c = 1
vdspline = InterpolatedUnivariateSpline(r, nf.d_v(r, pref), k=3)    #turns array vb into an approximate function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-44cd38d626e3> in <module>
#       4 pref = 1
#       5 #d_c = 1
# ----> 6 vdspline = InterpolatedUnivariateSpline(r, nf.d_v(r, pref), k=3)    #turns array vb into an approximate function
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_v(r, pref, save, load, **kwargs)
#     295         return a(r)
#     296     else:
# --> 297         return np.sqrt(-r*d_Fv(r,pref))
#     298
#     299 ################################
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    1970             vargs.extend([kwargs[_n] for _n in names])
#    1971
# -> 1972         return self._vectorize_call(func=func, args=vargs)
#    1973
#    1974     def _get_ufunc_and_otypes(self, func, args):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2040             res = func()
#    2041         else:
# -> 2042             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2043
#    2044             # Convert args to object arrays first
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2000
#    2001             inputs = [arg.flat[0] for arg in args]
# -> 2002             outputs = func(*inputs)
#    2003
#    2004             # Performance note: profiling indicates that -- for simple
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_F(r, pref)
#     280 def d_F(r,pref): #multiplying by upsylon
#     281     pref = lambda r: epsdisk*(L0/d_Mdblintrho(r,h=h_c,d_rho00=rho00_c))
# --> 282     return 4*np.pi*G*d_outerintegral(r,h=h_c,d_rho00=rho00_c)*pref(r,h=h_c,d_rho00=rho00_c)
#     283 d_Fv = np.vectorize(d_F)
#     284
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_outerintegral(r, h, d_rho00)
#     271
#     272 def d_outerintegral(r,h,d_rho00): #Integrate Outer Function
# --> 273     return si.quad(d_innerintegral, 0, np.inf, args=(r,h,d_rho00))[0]
#     274
#     275 def d_Mdblintrho(r,h,d_rho00):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\integrate\quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\integrate\quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
# --> 450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#     451     else:
#     452         if infbounds != 0:
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_innerintegral(u, r, h, d_rho00)
#     268
#     269 def d_innerintegral(u,r,h,d_rho00): #Integrate Function
# --> 270     return si.quad(d_innerfunc, 0, np.inf, args=(r,u,h,d_rho00))[0]
#     271
#     272 def d_outerintegral(r,h,d_rho00): #Integrate Outer Function
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\integrate\quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\integrate\quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
# --> 450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#     451     else:
#     452         if infbounds != 0:
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_innerfunc(z, r, u, h, d_rho00)
#     265
#     266 def d_innerfunc(z,r,u,h,d_rho00):  #Inner Function (3D)
# --> 267     return u*d_drho_rz(u, z, h, d_rho00)*(2*d_K(r,u,z))/(np.pi*np.sqrt(r*u*d_px(r,u,z)))
#     268
#     269 def d_innerintegral(u,r,h,d_rho00): #Integrate Function
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_drho_rz(r, z, h, d_rho00)
#     257     return d_rho0(r, h, d_rho00)*(np.power((np.cosh(z/z0)), (-2)))
#     258 def d_drho_rz(r,z,h,d_rho00):
# --> 259     return d_durho0(r, h, d_rho00)*(np.power(np.cosh(z/z0), -2))
#     260
#     261 #Disk Density Distribution (3D)
#
# ~\Documents\grav_project\python\NGC5533_functions.py in d_durho0(r, h, d_rho00)
#     250     condlist = [r <= R(h), (r > R(h)) & (r <= (R(h)+d(h))), r > (R(h)+d(h))]
#     251     funclist = [lambda r,h,d_rho00: -(1/h)*d_rho00*np.exp(-r/h), lambda r,h,d_rho00: -(1/d)*d_rho00*np.exp(-R/h), lambda r,h,d_rho00: 0]
# --> 252     return np.piecewise(r, h, d_rho00, condlist, funclist)
#     253     #Thinks that funclist is a float??
#     254
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py in piecewise(x, condlist, funclist, *args, **kw)
#     551     """
#     552     x = asanyarray(x)
# --> 553     n2 = len(funclist)
#     554
#     555     # undocumented: single condition is promoted to a list of one condition
#
# TypeError: object of type 'float' has no len()

# %%
# Black Hole

r = np.linspace(0.1,20,10)
#bh_c = 1
vbhspline = InterpolatedUnivariateSpline(r, nf.bh_v(r), k=3)    #turns array vb into an approximate function

# %%
# Halo

r = np.linspace(0.1,20,10)
#h_c = 1
vhalospline = InterpolatedUnivariateSpline(r, nf.h_v(r), k=3)    #turns array vb into an approximate function

# %%
# Spline plot

fig = plt.figure(figsize=(9.0,8.0))

plt.plot(r,vbspline(r),label='Bulge Spline')
#plt.plot(r,vdspline(r),label='Disk Spline')
plt.plot(r,vbhspline(r),label='Black Hole Spline')
plt.plot(r,vhalospline(r),label='Halo Spline')

plt.legend()
plt.show()
