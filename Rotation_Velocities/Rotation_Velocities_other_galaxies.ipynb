# %%
# Imports

import sys
sys.path.append('../python/')
import numpy as np
import matplotlib.pyplot as plt
import dataPython as dp

# %% [markdown]
# ## UGC 477

# %%
# Importing data
# Observed DensePak rotation curves from 
# Kuzio de Naray et al. 2006, ApJS, 165, 461 and
# Kuzio de Naray et al. 2008, ApJ, 676, 920

data = dp.getXYdata_wYerr('UGC477.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,60)
plt.ylim(0,200)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('UGC 477', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()

# %% [markdown]
# ## UGC 4325

# %%
# Importing data
# Observed DensePak rotation curves from 
# Kuzio de Naray et al. 2006, ApJS, 165, 461 and
# Kuzio de Naray et al. 2008, ApJ, 676, 920

data = dp.getXYdata_wYerr('UGC4325.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,60)
plt.ylim(0,200)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('UGC 4325', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()

# %% [markdown]
# ## UGC 1281

# %%
# Importing data
# Observed DensePak rotation curves from 
# Kuzio de Naray et al. 2006, ApJS, 165, 461 and
# Kuzio de Naray et al. 2008, ApJ, 676, 920

data = dp.getXYdata_wYerr('UGC1281.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,60)
plt.ylim(0,200)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('UGC 1281', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()

# %% [markdown]
# ## NGC 4594

# %%
# Importing data
#Velocity profiles of galaxies with claimed black holes —
#I. Observations of M31, M32, NGG 3115 and NGC 4594 
#van der Marel RP, Rix HW, Carter D, Franx M, White SDM, de Zeeuw T. 1994, MNRAS, 268, 521

data = dp.getXYdata_wYerr('NGC4594.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,60)
plt.ylim(0,400)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('NGC 4594', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()

# %% [markdown]
# ## UGC 2953

# %%
# Importing data
#SPARC is a database of 175 late-type galaxies (spirals and irregulars) with Spitzer photometry 
#at 3.6 mu (tracing the stellar mass distribution) and high-quality HI+Halpha rotation curves 
#(tracing the gravitational potential out to large radii).
#http://astroweb.cwru.edu/SPARC/

data = dp.getXYdata_wYerr('UGC2953.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,70)
plt.ylim(0,400)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('UGC 2953', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()

# %% [markdown]
# ## UGC 5253

# %%
# Importing data
#SPARC is a database of 175 late-type galaxies (spirals and irregulars) with Spitzer photometry 
#at 3.6 mu (tracing the stellar mass distribution) and high-quality HI+Halpha rotation curves 
#(tracing the gravitational potential out to large radii).
#http://astroweb.cwru.edu/SPARC/

data = dp.getXYdata_wYerr('UGC5253.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,60)
plt.ylim(0,400)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('UGC 5253', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()

# %% [markdown]
# ## UGC 6787

# %%
# Importing data
#SPARC is a database of 175 late-type galaxies (spirals and irregulars) with Spitzer photometry 
#at 3.6 mu (tracing the stellar mass distribution) and high-quality HI+Halpha rotation curves 
#(tracing the gravitational potential out to large radii).
#http://astroweb.cwru.edu/SPARC/

data = dp.getXYdata_wYerr('UGC6787.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,40)
plt.ylim(0,400)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('UGC 6787', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()

# %% [markdown]
# ## UGC 9133 (NGC 5533)

# %%
# Importing data
#SPARC is a database of 175 late-type galaxies (spirals and irregulars) with Spitzer photometry 
#at 3.6 mu (tracing the stellar mass distribution) and high-quality HI+Halpha rotation curves 
#(tracing the gravitational potential out to large radii).
#http://astroweb.cwru.edu/SPARC/

data = dp.getXYdata_wYerr('UGC9133.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,100)
plt.ylim(0,400)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('UGC 9133', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()

# %% [markdown]
# ## UGC 89

# %%
# Importing data
#GHASP survey https://academic.oup.com/mnras/article/388/2/500/976912#86133715

data = dp.getXYdata_wYerr('UGC89.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,13)
plt.ylim(0,450)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('UGC 89', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()

# %% [markdown]
# ## UGC 10075

# %%
# Importing data
#GHASP survey https://academic.oup.com/mnras/article/388/2/500/976912#86133715

data = dp.getXYdata_wYerr('UGC10075.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,15)
plt.ylim(0,200)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('UGC 10075', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()

# %% [markdown]
# ## UGC 1437

# %%
# Importing data
#GHASP survey https://academic.oup.com/mnras/article/388/2/500/976912#86133715

data = dp.getXYdata_wYerr('UGC1437.txt')
r_dat = np.asarray(data['xx'])
v_dat = np.asarray(data['yy'])
#v_err0 = np.asarray(data['ex'])
v_err1 = np.asarray(data['ey'])

# %%
# Plotting Rotational Velocities

fig = plt.figure(figsize=(9.0,8.0))

ax = plt.axes()
ax.grid(True)
ax.yaxis.grid(True,which='minor',linestyle='--')

plt.xlim(0,30)
plt.ylim(0,250)

plt.errorbar(r_dat,v_dat,yerr=v_err1,fmt='bo',label='Data')

ax.set_title('UGC 1437', fontsize=18)             
ax.set_xlabel('Radius (kpc)', fontsize=14)
ax.set_ylabel('Velocity (km/s)', fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14);

plt.legend()
plt.show()
