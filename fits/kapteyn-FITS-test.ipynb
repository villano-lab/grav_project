# %%
from kapteyn import maputils
from matplotlib import pyplot as plt

# %%
path = '../fits/UGC09133/'

f = maputils.FITSimage(path+'UGC_09133_HR_I21cmh2002.fits')
mplim = f.Annotatedimage()
im = mplim.Image()
mplim.plot()

plt.show()

# %%
f = maputils.FITSimage(path+'UGC_09133s30cl_I_HI_h2011.fits')
mplim = f.Annotatedimage()
im = mplim.Image()
mplim.plot()

plt.show()

# %%
f = maputils.FITSimage(path+'UGC_09133s60cl_I_HI_h2011.fits')
mplim = f.Annotatedimage()
im = mplim.Image()
mplim.plot()

plt.show()

# %%
f = maputils.FITSimage(path+'UGC_09133cl_I_HI_h2011.fits')
mplim = f.Annotatedimage()
im = mplim.Image()
mplim.plot()

plt.show()
